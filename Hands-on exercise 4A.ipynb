# %%
# Secure log in System

# %%
user_name = "true"
password = "true"
account_locked = "false"
access = user_name and password and not account_locked

print(access)
print("Access Granted ✅")
# Out:
# False
# Access Granted ✅

# %%
# University Scholarship Eligibility

# %%
student_score = 85
paticipated_in_EA = "ture"
low_income_famly = "fales"
print(student_score >= 80 and paticipated_in_EA or low_income_famly)
print("Congratulations!")
print("Schoolarship Approved")
# Out:
# ture
# Congratulations!
# Schoolarship Approved

# %%
# Smart Server Health Monitor

# %%
cpu_usage = 75
memory_usage = 95
disk_usage = 60
emergency_alert = cpu_usage >= 90 or memory_usage >= 90 or disk_usage >= 95
print(emergency_alert)
print("Server Health Alert: Critical Alert ⚠️")
# Out:
# True
# Server Health Alert: Critical Alert ⚠️

# %%
# Online Shoping Platform
