# %%
#Employee Payroll & Bonus Eligibility

# %%
basic_salary = 180000
bonus = 45000
total_earned = basic_salary + bonus
print("Total Salary:", total_earned)
print("Enligible for Premium Benefits:" , total_earned>=220000)
# Out:
# Total Salary: 225000
# Enligible for Premium Benefits: True

# %%
#Student Performance Evaluation

# %%
python = 72
sql = 65
excel = 80
power_bi = 75
total_score = Python + SQL + Excel + power_bi
average_score = total_score // 4
print("Average Score:" , average_score)
print("Pass", average_score >= 70)
# Out:
# Average Score: 73
# Pass True

# %%
# Inventory Management System

# %%
initial_stock = 250
sold = 85
remaining_stock = initial_stock - sold
print("Remaining Stock:" , remaining_stock)
print("Restock Needed:" , remaining_stock <= 200)
# Out:
# Remaining Stock: 165
# Restock Needed: True

# %%
# Banking Withdrawal Checker

# %%
account_balance = 520000
withdrawal_request = 150000
remaining_balance = account_balance - withdrawal_request
wathdrawal_approved = account_balance >= withdrawal_request
print("Remaining Balance:" , remaining_balance)
print("Withdrawal Approved:" , wathdrawal_approved)
# Out:
# Remaining Balance: 370000
# Withdrawal Approved: True

# %%
# Smart Shopping Discount Calculator

# %%
laptop_bag = 18500
wireless_mouse = 12000
keyboard = 24500
usb_drive = 5000
total_purchase = laptop_bag + wireless_mouse + keyboard + usb_drive
discount = total_purchase // 10
print("Total Purchase:" , total_purchase)
print("Discount Qualified:" , total_purchase >= 50000)
print("Discount Amount:" ,  discount)
print("Amount to Pay:" , total_purchase - discount)
# Out:
# Total Purchase: 60000
# Discount Qualified: True
# Discount Amount: 6000
# Amount to Pay: 54000
