# %%
# My welcome note

# %%
print("Hello, World!")
print("My name is Emmanuel")
print("I am learning Python.")
print("Progamming is exciting")
# Out:
# Hello, World!
# My name is Emmanuel
# I am learning Python.
# Progamming is exciting

# %%
# My favorites

# %%
print("My favorite food is: Beans and Plantain")
print("My favorite movies is: Avatar the last air bender")
print("My favorite sport is: Volley ball")
print("My favorite color is: Red")
# Out:
# My favorite food is: Beans and Plantain
# My favorite movies is: Avatar the last air bender
# My favorite sport is: Volley ball
# My favorite color is: Red

# %%
# Python Calculator

# %%
print(15 + 5)
print(30 - 12)
print(9 * 8)
print(72 / 9)
print(18 % 5)
print(10 // 3)
print(5**2)
# Out:
# 20
# 18
# 72
# 8.0
# 3
# 3
# 25

# %%
# mini challege

# %%
# My Name
print("My name is: Emmanuel")
# My Dream Job
print("My dreamer career is to be an Ethical hacker")
# My Country
print("I am from NIgeria")
# Python Maths
print(25+75)
print(40//6)
print(8**2)
# Out:
# My name is: Emmanuel
# My dreamer career is to be an Ethical hacker
# I am from NIgeria
# 100
# 6
# 64
