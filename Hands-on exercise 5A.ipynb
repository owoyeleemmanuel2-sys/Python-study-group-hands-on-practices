# %%
#Ex. 1 
# Company Name: StarX Digital Solution
# Customer Registration System
name = "Name:"
address = "Address:"
phone_number = "Phone:"
country = "Counrty:"
occupation = "Occupation:"
print("Customer Registration")
print(name)
print(address)
print(phone_number)
print(country)
print(occupation)
# Out:
# Customer Registration
# Name:
# Address:
# Phone:
# Counrty:
# Occupation:

# %%
# Ex. 2
# Hospital Patient Record
patient_record = """Patient: Adedejo Alao
Doctor: Gab fangs
Diagnosis: Ulcer
Blood Group: O-
Hospital: Rehobot Hospital"""
print(patient_record)
# Out:
# Patient: Adedejo Alao
# Doctor: Gab fangs
# Diagnosis: Ulcer
# Blood Group: O-
# Hospital: Rehobot Hospital

# %%
# Ex. 3
#  AI Prompt Builder
# Create a multiline string prompt using triple quotes
prompt = """You are an AI assistant.
Instructions:
1. Analyze customer feedback.
2. Identify common complaints.
3. Provide recommendations.
4. Generate a summary report with: Total feedback, Top 3 complaints, and Key Recommendations."""
print(prompt)
# Out:
# You are an AI assistant.
# Instructions:
# 1. Analyze customer feedback.
# 2. Identify common complaints.
# 3. Provide recommendations.
# 4. Generate a summary report with: Total feedback, Top 3 complaints, and Key Recommendations.

# %%
# Real World Case Study Project

# Customer Feedback Management System
customer_feedback_report = '''========================================
        CUSTOMER FEEDBACK REPORT
========================================
Customer Name: Hannah
Product: JBL Boombox 2
Category: Sounds and Eletrinics
Rating: 4 star

Customer Review
--------------------
The product is giving an amazing dare 
to listen sound and the bass in breath 
taking but the delivery period was not
fast enough.

========================================
    """Thank you for your feedback!"""
========================================'''
print(customer_feedback_report)
# Out:
# ...
#         CUSTOMER FEEDBACK REPORT
# ...
# Customer Name: Hannah
# Product: JBL Boombox 2
# Category: Sounds and Eletrinics
# Rating: 4 star
#
# Customer Review
# --------------------
# The product is giving an amazing dare
# to listen sound and the bass in breath
# taking but the delivery period was not
# fast enough.
#
# ...
#     """Thank you for your feedback!"""
# ...
