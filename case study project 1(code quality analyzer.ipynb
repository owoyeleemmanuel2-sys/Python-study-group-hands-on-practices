# %%
# Software Quality Information

# %%
# Smart Inventory API

# %%
# Code Quality Analyzer
developer_name = "Sarah Johnson"
total_test_case = 120
total_test_passed = 112
critical_bugs = 2
maximum_acceptable_critical_bugs = 3
additional_test_passed = 5
minimum_pass_rate_required = 90 #(%)
build_completed_successfully = True
# calculating the percentage of test cases that passed
pass_rate = (total_test_passed / total_test_case) * 100
print("Pass Rate:", pass_rate,"%",)
# Updated test result
latest_test_passed = total_test_passed + additional_test_passed
updated_passed_rate = (latest_test_passed / total_test_case) * 100
print("Updated Passed Rate:", updated_passed_rate,"%")
# checking if the pass rate meets the standard
pass_rate_met = updated_passed_rate >= minimum_pass_rate_required
print("Pass rate met:", pass_rate_met)
# checking if the number of critical bugs is acceptable
critical_bugs_accepted = critical_bugs <= maximum_acceptable_critical_bugs
print("Number of critical bug is accepted:", critical_bugs_accepted)
# determining release readiness
pass_rate_met = updated_passed_rate >= minimum_pass_rate_required
build_completed_successfully = pass_rate_met == critical_bugs_accepted
ready_for_release = build_completed_successfully and pass_rate_met
print("Build completed succesfully:", build_completed_successfully)
print("Ready for release:", ready_for_release)
# determining if engineering review is required
engineering_review_required = pass_rate_met != critical_bugs_accepted or critical_bugs >= maximum_acceptable_critical_bugs
print("Engineering review required:", engineering_review_required)
# Out:
# Pass Rate: 93.33333333333333 %
# Updated Passed Rate: 97.5 %
# Pass rate met: True
# Number of critical bug is accepted: True
# Build completed succesfully: True
# Ready for release: True
# Engineering review required: False

# %%
print("=========================================================")
print("CODE QUALITY ANALYSIS REPORT"                  )
print("=========================================================")
print("Project Name: Smart Inventory API")
print("Developer: Sara Johnson")
print("Total Test Case: 120")
print("Updated Test Case Passed: 117")
print("Updated Pass Rate: 97.50%")
print("Critical Bugs Found: 2")
print("Maximum Acceptable Critical Bug:")
print("Pass Rate Requirement Met: True")
print("Critical Bug Within Limit: True")
print("Build Completed Succesfully: True")
print("Ready For Release: True")
print("Engineering Review Required: False")
print("==========================================================")
# Out:
# ...
# CODE QUALITY ANALYSIS REPORT
# ...
# Project Name: Smart Inventory API
# Developer: Sara Johnson
# Total Test Case: 120
# Updated Test Case Passed: 117
# Updated Pass Rate: 97.50%
# Critical Bugs Found: 2
# Maximum Acceptable Critical Bug:
# Pass Rate Requirement Met: True
# Critical Bug Within Limit: True
# Build Completed Succesfully: True
# Ready For Release: True
# Engineering Review Required: False
# ...
